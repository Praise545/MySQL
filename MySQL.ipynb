# %%
import mysql.connector

# %%
db = mysql.connector.connect(
    host="localhost",
    user="root",
    passwd="uche",
    database=""
    )

# %%
mycursor = db.cursor()

# %%
#mycursor.execute("CREATE TABLE Person (name VARCHAR(20), age smallint UNSIGNED, personID int PRIMARY KEY AUTO_INCREMENT)")

# %%
#mycursor.execute("INSERT INTO Person (name, age) VALUES (%s,%s)", ("Joe", 19))
#db.commit()
#mycursor.execute("SELECT * FROM Person")

# %%
#for x in mycursor:
    #print(x)

# %%
#mycursor.execute("CREATE TABLE sit (name varchar(20) NOT NULL, created datetime NOT NULL, gender ENUM('M', 'F', '0') NOT NULL, id int PRIMARY KEY NOT NULL AUTO_INCREMENT)")

# %%
#mycursor.execute("INSERT INTO sit (name, created, gender) VALUES(%s,%s,%s)", ("TIM", datetime.now(), "M"))
#db.commit()

# %% [markdown]
# #mycursor.execute("SELECT * FROM Test WHERE gender * 'M' ORDER BY id DESC")
# mycursor.execute("SHOW DATABASES")
# for x in mycursor:
#     print(x)

# %%
mycursor = db.cursor()

mycursor.execute("SHOW TABLES")

for x in mycursor:
  print(x)
# Out:
# ('actor',)
# ('actor_info',)
# ('address',)
# ('category',)
# ('city',)
# ('country',)
# ('customer',)
# ('customer_list',)
# ('faac_2020',)
# ('film',)
# ('film_actor',)
# ('film_category',)
# ('film_list',)
# ('film_text',)
# ('inventory',)
# ('language',)
# ('nicer_but_slower_film_list',)
# ('payment',)
# ('rental',)
# ('sales_by_film_category',)
# ('sales_by_store',)
# ('staff',)
# ('staff_list',)
# ('store',)

# %%
mycursor = db.cursor()
mycursor.execute("SELECT * FROM faac_2020")
myresult = mycursor.fetchall()
for x in myresult:
    print(x)
# Out:
# (1, 'ABIA STATE', 2856640370, 2646920172, 2363484966, 2688879058, 2490155558, 2250421954, 2734858404, 2810930839, 2773895905, 2596618258)
# (2, 'ADAMAWA STATE', 3558570430, 3299781555, 2951196566, 3342944259, 3107031846, 2806790553, 3422409363, 3521173689, 3469056745, 3245543006)
# (3, 'AKWA IBOW STATE', 4787699108, 4480229192, 3975088679, 4519596452, 4184880669, 3771090719, 4587373302, 4717716605, 4642221805, 4341768102)
# (4, 'ANAMBRA STSTE', 3664816610, 3379305620, 3034416217, 3445664112, 3197689890, 2894086980, 3506918152, 3652901346, 3619022330, 3405984445)
# (5, 'BAUCHI STATE', 4039919496, 3738855319, 3353442557, 3804630021, 3537197522, 3188040146, 3878092965, 3983143760, 3943155666, 3704418262)
# (6, 'BAYELSA STATE', 1633939426, 1550936159, 1374002332, 1539824664, 1462036983, 1295228924, 1568937191, 1600343397, 1601635186, 1494693258)
# (7, 'BENUE STATE', 4223851998, 3896596114, 3463541420, 3945070871, 3811578838, 3432016945, 4159104745, 4276390960, 4250539470, 3958235984)
# (8, 'BORNO STATE', 4758159137, 4397582151, 3938928589, 4471277526, 4164819788, 3740754843, 4545066619, 4668850626, 4604694090, 4311309574)
# (9, 'CROSS-RIVER STATE', 3054200372, 2824287948, 2525596284, 2868068399, 2704875775, 2434720698, 2962334529, 3040418003, 3002500951, 2811179250)
# (10, 'DELTA STATE', 4111298336, 3804384843, 3357915895, 3840198232, 3687491597, 3258598922, 3967940067, 4018714705, 3981350398, 3738568339)
# (11, 'EBONYI STATE', 2268707806, 2101351354, 1863424036, 2175618814, 2032712657, 1836944957, 2214383863, 2295217926, 2250801402, 2122765904)
# (12, 'EDO STATE', 3087218418, 2646920172, 2565263953, 2903682949, 2690190321, 2436244969, 2960451005, 3052677575, 3000302456, 2823032749)
# (13, 'EKITI STATE', 2469231151, 2284185260, 2045554153, 2326392621, 2152765023, 1953709758, 2384508272, 2437212212, 2426876508, 2289194190)
